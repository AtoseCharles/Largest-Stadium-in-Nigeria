# %%
#Atose Charles Efe
#VEPH/20A/DA0493
#Task 69

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_stadiums_in_Nigeria'

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of stadiums in Nigeria - Wikipedia</title>
# ...

# %%
tables =soup.find_all('table')

# %%
print(tables)
# Out:
# [<table class="wikitable sortable">
# <tbody><tr>
# <th>#
# </th>
# <th>Stadium
# </th>
# <th>Capacity
# </th>
# <th>Commissioned
# </th>
# <th>City
# </th>
# <th>State
# </th>
# <th>Tenants
# </th>
# <th>Ref
# </th>
# <th>Images
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a class="mw-redirect" href="/wiki/Abuja_National_Stadium" title="Abuja National Stadium">Moshood Abiola National Stadium</a>
# </td>
# <td>60,491
# </td>
# <td>2003
# </td>
# <td><a href="/wiki/Abuja" title="Abuja">Abuja</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Federal_Capital_Territory,_Nigeria" title="Federal Capital Territory, Nigeria">FCT</a>
# </td>
# <td><a href="/wiki/Nigeria_national_football_team" title="Nigeria national football team">Nigeria national football team</a>
# </td>
# <td><sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
# </td>
# ...

# %%
table =soup.find_all('th')

# %%
print(table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Stadium</th>
# <th>Capacity</th>
# <th>City</th>
# <th>Tenants</th>
# <th>Planned opening
# </th></tr>
# <tr>
# <td><a href="/wiki/Lagos_Arena" title="Lagos Arena">Lagos Arena</a></td>
# <td>12,000<sup class="reference" id="cite_ref-25"><a href="#cite_note-25"><span class="cite-bracket">[</span>25<span class="cite-bracket">]</span></a></sup></td>
# <td><a href="/wiki/Lagos" title="Lagos">Lagos</a></td>
# <td><a href="/wiki/Nigeria_men%27s_national_basketball_team" title="Nigeria men's national basketball team">Nigeria men's national basketball team</a></td>
# <td>2025
# </td></tr>
# <tr>
# <td><a href="/wiki/Edo_Arena" title="Edo Arena">Edo Arena</a></td>
# <td>6,000</td>
# <td><a href="/wiki/Benin_City" title="Benin City">Benin City</a></td>
# <td><a href="/wiki/Bendel_Insurance_F.C." title="Bendel Insurance F.C.">Bendel Insurance F.C.</a></td>
# <td>2025
# </td></tr>
# </tbody></table>

# %%
Table = soup.find_all('table')[0]

# %%
print(Table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>#
# </th>
# <th>Stadium
# </th>
# <th>Capacity
# </th>
# <th>Commissioned
# </th>
# <th>City
# </th>
# <th>State
# </th>
# <th>Tenants
# </th>
# <th>Ref
# </th>
# <th>Images
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a class="mw-redirect" href="/wiki/Abuja_National_Stadium" title="Abuja National Stadium">Moshood Abiola National Stadium</a>
# </td>
# <td>60,491
# </td>
# <td>2003
# </td>
# <td><a href="/wiki/Abuja" title="Abuja">Abuja</a>
# </td>
# <td><a class="mw-redirect" href="/wiki/Federal_Capital_Territory,_Nigeria" title="Federal Capital Territory, Nigeria">FCT</a>
# </td>
# <td><a href="/wiki/Nigeria_national_football_team" title="Nigeria national football team">Nigeria national football team</a>
# </td>
# <td><sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
# </td>
# ...

# %%
header = Table.find_all('th')

# %%
print(header)
# Out:
# [<th>#
# </th>, <th>Stadium
# </th>, <th>Capacity
# </th>, <th>Commissioned
# </th>, <th>City
# </th>, <th>State
# </th>, <th>Tenants
# </th>, <th>Ref
# </th>, <th>Images
# </th>]

# %%
world_title_table = [title.text.strip() for title in header]

# %%
print(world_title_table)
# Out:
# ['#', 'Stadium', 'Capacity', 'Commissioned', 'City', 'State', 'Tenants', 'Ref', 'Images']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_title_table)

# %%
df
# Out:
# Empty DataFrame
# Columns: [#, Stadium, Capacity, Commissioned, City, State, Tenants, Ref, Images]
# Index: []

# %%
column_data = Table.find_all('tr')

# %%
#print(column_data)

# %%
for row in column_data[1:]:
    Row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in Row_data]
    print(individual_row_data)
# Out:
# ['1', 'Moshood Abiola National Stadium', '60,491', '2003', 'Abuja', 'FCT', 'Nigeria national football team', '[1]', '']
# ['2', 'Jos International Stadium', '60,000', '', 'Jos', 'Plateau', '', '[2][3]', '']
# ['3', 'Lagos National Stadium', '45,000', '1972', 'Lagos', 'Lagos', 'Cowrie Rugby Football Club', '', '']
# ['4', 'Adokiye Amiesimaka Stadium', '38,000', '2015', 'Port Harcourt', 'Rivers', '', '', '']
# ['5', 'Muhammadu Dikko Stadium', '35,000', '2013', 'Katsina', 'Katsina', 'Katsina United F.C.', '', '']
# ['6', 'Godswill Akpabio International Stadium', '30,000', '2014', 'Uyo', 'Akwa Ibom', 'Akwa United', '[4][5]', '']
# ['7', 'Rojenny International Stadium', '30,000', '', 'Oba', 'Anambra', '', '', '']
# ['8', 'Confluence Stadium', '25,000', '', 'Lokoja', 'Kogi', '', '', '']
# ['9', 'Obafemi Awolowo Stadium', '25,000', '', 'Ibadan', 'Oyo', '', '', '']
# ['10', 'Teslim Balogun Stadium', '24,325', '2007', 'Surulere', 'Lagos', 'First Bank F.C.', '', '']
# ...

# %%
for row in column_data[1:]:
    Row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in Row_data]
    
    if len(individual_row_data) == len(df.columns):
     df.loc[len(df)] = individual_row_data

# %%
df
# Out:
#       #                          Stadium Capacity Commissioned           City  \
# 0     1  Moshood Abiola National Stadium   60,491         2003          Abuja
# 1     2        Jos International Stadium   60,000                         Jos
# 2     3           Lagos National Stadium   45,000         1972          Lagos
# 3     4       Adokiye Amiesimaka Stadium   38,000         2015  Port Harcourt
# 4     5          Muhammadu Dikko Stadium   35,000         2013        Katsina
# ..   ..                              ...      ...          ...            ...
# 310  55         Umuahia Township Stadium    5,000
# 311  56         Yenagoa Township Stadium    5,000
# 312  57               Ebedi City Stadium    5,000                      Iseyin
# 313  58              Uniport Sport Arena    5,000               Port Harcourt
# 314  59                    Agege Stadium    4,000
#
#        State                                       Tenants            Ref  \
# ...

# %%
df.to_csv(r'C:\Users\ROG\Desktop\pratical dataset\stadium_in_nigeria.csv', index = False)
